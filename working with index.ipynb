# %%
import pandas as pd

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# ### Making country column as index at the time of reading the Data

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry', index_col = 'country')

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks2 = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks2.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# ### making country column as index

# %%
drinks.set_index(['country']).head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %% [markdown]
# ### Making 2 Index

# %%
drinks.set_index(['continent','country']).head()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# Asia      Afghanistan              0                0              0
# Europe    Albania                 89              132             54
# Africa    Algeria                 25                0             14
# Europe    Andorra                245              138            312
# Africa    Angola                 217               57             45
#
#                        total_litres_of_pure_alcohol
# continent country
# Asia      Afghanistan                           0.0
# Europe    Albania                               4.9
# Africa    Algeria                               0.7
# Europe    Andorra                              12.4
# Africa    Angola                                5.9

# %%
drinks.continent.value_counts()['Africa']
# Out:
# 53
