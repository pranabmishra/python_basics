# %% [markdown]
# # Pivot Table

# %%
import pandas as pd

# %%
df = pd.read_excel('https://github.com/datagy/pivot_table_pandas/raw/master/sample_pivot.xlsx', parse_dates=['Date'])

# %%
df.head()
# Out:
#         Date Region                 Type  Units  Sales
# 0 2020-07-11   East  Children's Clothing   18.0    306
# 1 2020-09-23  North  Children's Clothing   14.0    448
# 2 2020-04-02  South     Women's Clothing   17.0    425
# 3 2020-02-28   East  Children's Clothing   26.0    832
# 4 2020-03-19   West     Women's Clothing    3.0     33

# %%
pivot = pd.pivot_table(df, index = ['Region', 'Type'], values = 'Sales', aggfunc = 'sum') 
pivot
# Out:
#                             Sales
# Region Type
# East   Children's Clothing  45849
#        Men's Clothing       51685
#        Women's Clothing     70229
# North  Children's Clothing  37306
#        Men's Clothing       39975
#        Women's Clothing     61419
# South  Children's Clothing  18570
#        Men's Clothing       18542
#        Women's Clothing     22203
# West   Children's Clothing  20182
#        Men's Clothing       19077
#        Women's Clothing     22217

# %%
pivot.style.format({'Sales':'${0:,.0f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_7376b650_921e_11ea_bb7c_1062e58b12fe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sales</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="index_name level1" >Type</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel0_row0" class="row_heading level0 row0" rowspan=3>East</th>
#                         <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row0" class="row_heading level1 row0" >Children's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow0_col0" class="data row0 col0" >$45,849</td>
#             </tr>
#             <tr>
#                                 <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row1" class="row_heading level1 row1" >Men's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow1_col0" class="data row1 col0" >$51,685</td>
#             </tr>
#             <tr>
#                                 <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row2" class="row_heading level1 row2" >Women's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow2_col0" class="data row2 col0" >$70,229</td>
#             </tr>
#             <tr>
#                         <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel0_row3" class="row_heading level0 row3" rowspan=3>North</th>
#                         <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row3" class="row_heading level1 row3" >Children's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow3_col0" class="data row3 col0" >$37,306</td>
#             </tr>
#             <tr>
#                                 <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row4" class="row_heading level1 row4" >Men's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow4_col0" class="data row4 col0" >$39,975</td>
#             </tr>
#             <tr>
#                                 <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row5" class="row_heading level1 row5" >Women's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow5_col0" class="data row5 col0" >$61,419</td>
#             </tr>
#             <tr>
#                         <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel0_row6" class="row_heading level0 row6" rowspan=3>South</th>
#                         <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row6" class="row_heading level1 row6" >Children's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow6_col0" class="data row6 col0" >$18,570</td>
#             </tr>
#             <tr>
#                                 <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row7" class="row_heading level1 row7" >Men's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow7_col0" class="data row7 col0" >$18,542</td>
#             </tr>
#             <tr>
#                                 <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row8" class="row_heading level1 row8" >Women's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow8_col0" class="data row8 col0" >$22,203</td>
#             </tr>
#             <tr>
#                         <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel0_row9" class="row_heading level0 row9" rowspan=3>West</th>
#                         <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row9" class="row_heading level1 row9" >Children's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow9_col0" class="data row9 col0" >$20,182</td>
#             </tr>
#             <tr>
#                                 <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row10" class="row_heading level1 row10" >Men's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow10_col0" class="data row10 col0" >$19,077</td>
#             </tr>
#             <tr>
#                                 <th id="T_7376b650_921e_11ea_bb7c_1062e58b12felevel1_row11" class="row_heading level1 row11" >Women's Clothing</th>
#                         <td id="T_7376b650_921e_11ea_bb7c_1062e58b12ferow11_col0" class="data row11 col0" >$22,217</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # From Code Basics

# %%
df = pd.read_csv('.//data/weather.csv.txt')

# %%
df.head()
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83

# %%
pivot = df.pivot(index ='date', columns = 'city')

# %%
pivot
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
pivot2 = pd.pivot_table(df,index = ['date', 'city'], values = ('temperature', 'humidity'), aggfunc = 'mean')
pivot2

#pivot = pd.pivot_table(df, index = ['Region', 'Type'], values = 'Sales', aggfunc = 'sum')
# Out:
#                    humidity  temperature
# date     city
# 5/1/2017 beijing         26           80
#          mumbai          80           75
#          new york        56           65
# 5/2/2017 beijing         30           77
#          mumbai          83           78
#          new york        58           66
# 5/3/2017 beijing         35           79
#          mumbai          85           82
#          new york        60           68

# %%
pivot3 = pd.pivot_table(df,index = [ 'city','date'], values = ('temperature', 'humidity'), aggfunc = 'mean')
pivot3
# Out:
#                    humidity  temperature
# city     date
# beijing  5/1/2017        26           80
#          5/2/2017        30           77
#          5/3/2017        35           79
# mumbai   5/1/2017        80           75
#          5/2/2017        83           78
#          5/3/2017        85           82
# new york 5/1/2017        56           65
#          5/2/2017        58           66
#          5/3/2017        60           68

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.groupby(['date', 'city']).mean()
# Out:
#                    temperature  humidity
# date     city
# 5/1/2017 beijing            80        26
#          mumbai             75        80
#          new york           65        56
# 5/2/2017 beijing            77        30
#          mumbai             78        83
#          new york           66        58
# 5/3/2017 beijing            79        35
#          mumbai             82        85
#          new york           68        60
