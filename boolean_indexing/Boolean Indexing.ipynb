# %%
import pandas as pd

# %%
bikes= pd.read_csv('bikes.csv', parse_dates = ['starttime',  'stoptime'])

# %%
bikes.head(2)
# Out:
#    trip_id    usertype gender           starttime            stoptime  \
# 0     7147  Subscriber   Male 2013-06-28 19:01:00 2013-06-28 19:17:00
# 1     7524  Subscriber   Male 2013-06-28 22:53:00 2013-06-28 23:03:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St        41.88105
# 1           623  Clinton St & Washington Blvd        41.88338
#
#    longitude_start  dpcapacity_start        to_station_name  latitude_end  \
# 0        -87.61697              11.0  Michigan Ave & Oak St      41.90096
# 1        -87.64117              31.0   Wells St & Walton St      41.89993
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy

# %% [markdown]
# ##### print all column name

# %%
bikes.columns
# Out:
# Index(['trip_id', 'usertype', 'gender', 'starttime', 'stoptime',
#        'tripduration', 'from_station_name', 'latitude_start',
#        'longitude_start', 'dpcapacity_start', 'to_station_name',
#        'latitude_end', 'longitude_end', 'dpcapacity_end', 'temperature',
#        'visibility', 'wind_speed', 'precipitation', 'events'],
#       dtype='object')

# %% [markdown]
# ### Select Temp greater than 90

# %%
temp = bikes['temperature'] >90
temp.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: temperature, dtype: bool

# %%
temp[temp].head()
# Out:
# 54    True
# 55    True
# 56    True
# 61    True
# 62    True
# Name: temperature, dtype: bool

# %% [markdown]
# ### Select the temp less than 0 and Greater than 95

# %%
bike_temp = bikes['temperature']  # Creating a new variable for bike Temperature

# %%
filt1 =bike_temp <0
filt2 = bike_temp >95
filt3 = filt1 | filt2
bike_temp[filt3].head()
# Out:
# 395     96.1
# 396     96.1
# 397     96.1
# 1871    -2.0
# 2049    -2.0
# Name: temperature, dtype: float64

# %% [markdown]
# # Re Read the same data Frame with starttime index

# %%
bikes2 = pd.read_csv('bikes.csv',parse_dates = ['starttime', 'stoptime'],index_col = 'starttime' )

# %%
bikes2.head(2)
# Out:
#                      trip_id    usertype gender            stoptime  \
# starttime
# 2013-06-28 19:01:00     7147  Subscriber   Male 2013-06-28 19:17:00
# 2013-06-28 22:53:00     7524  Subscriber   Male 2013-06-28 23:03:00
#
#                      tripduration             from_station_name  \
# starttime
# 2013-06-28 19:01:00           993     Lake Shore Dr & Monroe St
# 2013-06-28 22:53:00           623  Clinton St & Washington Blvd
#
#                      latitude_start  longitude_start  dpcapacity_start  \
# starttime
# 2013-06-28 19:01:00        41.88105        -87.61697              11.0
# 2013-06-28 22:53:00        41.88338        -87.64117              31.0
#
#                            to_station_name  latitude_end  longitude_end  \
# starttime
# 2013-06-28 19:01:00  Michigan Ave & Oak St      41.90096     -87.623777
# 2013-06-28 22:53:00   Wells St & Walton St      41.89993     -87.634430
#
#                      dpcapacity_end  temperature  visibility  wind_speed  \
# ...

# %% [markdown]
# ### Select Temp greater than 90  WIth Dates

# %%
temp = bikes2['temperature']
temp.head()
# Out:
# starttime
# 2013-06-28 19:01:00    73.9
# 2013-06-28 22:53:00    69.1
# 2013-06-30 14:43:00    73.0
# 2013-07-01 10:05:00    72.0
# 2013-07-01 11:16:00    73.0
# Name: temperature, dtype: float64

# %% [markdown]
# ### Select the temp less than 0 and Greater than 95 With dates

# %%
bike_temp = bikes2['temperature']
filt1 =bike_temp <0
filt2 = bike_temp >95
filt3 = filt1 | filt2
bike_temp[filt3].head()
# Out:
# starttime
# 2013-08-30 15:33:00    96.1
# 2013-08-30 15:37:00    96.1
# 2013-08-30 15:49:00    96.1
# 2013-12-12 05:13:00    -2.0
# 2014-01-23 06:15:00    -2.0
# Name: temperature, dtype: float64

# %% [markdown]
# # Between Method

# %%
filt = (bike_temp > 50) & (bike_temp < 60)
bike_temp[filt].head()
# Out:
# starttime
# 2013-09-13 07:55:00    54.0
# 2013-09-13 08:04:00    57.9
# 2013-09-13 08:04:00    57.9
# 2013-09-13 08:06:00    57.9
# 2013-09-13 08:22:00    57.9
# Name: temperature, dtype: float64

# %%
# second method , can be used between method

bike_temp[bike_temp.between(50,60)].head()
# Out:
# starttime
# 2013-09-13 07:55:00    54.0
# 2013-09-13 08:04:00    57.9
# 2013-09-13 08:04:00    57.9
# 2013-09-13 08:06:00    57.9
# 2013-09-13 08:22:00    57.9
# Name: temperature, dtype: float64

# %%
bikes2[bike_temp.between(50,60)].head()   # to get the complete dataframe
# Out:
#                      trip_id    usertype  gender            stoptime  \
# starttime
# 2013-09-13 07:55:00   483022  Subscriber  Female 2013-09-13 08:01:00
# 2013-09-13 08:04:00   483128  Subscriber    Male 2013-09-13 08:16:00
# 2013-09-13 08:04:00   483127  Subscriber  Female 2013-09-13 08:14:00
# 2013-09-13 08:06:00   483157  Subscriber  Female 2013-09-13 08:14:00
# 2013-09-13 08:22:00   483352  Subscriber    Male 2013-09-13 08:42:00
#
#                      tripduration               from_station_name  \
# starttime
# 2013-09-13 07:55:00           319   Greenview Ave & Fullerton Ave
# 2013-09-13 08:04:00           738      Lincoln Ave & Armitage Ave
# 2013-09-13 08:04:00           599             Orleans St & Elm St
# 2013-09-13 08:06:00           493    Michigan Ave & Washington St
# 2013-09-13 08:22:00          1215  Southport Ave & Wellington Ave
#
#                      latitude_start  longitude_start  dpcapacity_start  \
# starttime
# ...

# %% [markdown]
# ### Simultaneous between selection of rows and column labels with loc

# %%
bikes2.head(2)
# Out:
#                      trip_id    usertype gender            stoptime  \
# starttime
# 2013-06-28 19:01:00     7147  Subscriber   Male 2013-06-28 19:17:00
# 2013-06-28 22:53:00     7524  Subscriber   Male 2013-06-28 23:03:00
#
#                      tripduration             from_station_name  \
# starttime
# 2013-06-28 19:01:00           993     Lake Shore Dr & Monroe St
# 2013-06-28 22:53:00           623  Clinton St & Washington Blvd
#
#                      latitude_start  longitude_start  dpcapacity_start  \
# starttime
# 2013-06-28 19:01:00        41.88105        -87.61697              11.0
# 2013-06-28 22:53:00        41.88338        -87.64117              31.0
#
#                            to_station_name  latitude_end  longitude_end  \
# starttime
# 2013-06-28 19:01:00  Michigan Ave & Oak St      41.90096     -87.623777
# 2013-06-28 22:53:00   Wells St & Walton St      41.89993     -87.634430
#
#                      dpcapacity_end  temperature  visibility  wind_speed  \
# ...

# %%
#bike_temp = bikes2['temperature']
filt = bike_temp.between(50,60)
cols = ['temperature', 'events']
bikes2.loc[filt,cols].head()
# Out:
#                      temperature        events
# starttime
# 2013-09-13 07:55:00         54.0  partlycloudy
# 2013-09-13 08:04:00         57.9  partlycloudy
# 2013-09-13 08:04:00         57.9  partlycloudy
# 2013-09-13 08:06:00         57.9  partlycloudy
# 2013-09-13 08:22:00         57.9  partlycloudy

# %% [markdown]
# ## column to column comparision

# %%
bikes2.head()
# Out:
#                      trip_id    usertype gender            stoptime  \
# starttime
# 2013-06-28 19:01:00     7147  Subscriber   Male 2013-06-28 19:17:00
# 2013-06-28 22:53:00     7524  Subscriber   Male 2013-06-28 23:03:00
# 2013-06-30 14:43:00    10927  Subscriber   Male 2013-06-30 15:01:00
# 2013-07-01 10:05:00    12907  Subscriber   Male 2013-07-01 10:16:00
# 2013-07-01 11:16:00    13168  Subscriber   Male 2013-07-01 11:18:00
#
#                      tripduration             from_station_name  \
# starttime
# 2013-06-28 19:01:00           993     Lake Shore Dr & Monroe St
# 2013-06-28 22:53:00           623  Clinton St & Washington Blvd
# 2013-06-30 14:43:00          1040  Sheffield Ave & Kingsbury St
# 2013-07-01 10:05:00           667       Carpenter St & Huron St
# 2013-07-01 11:16:00           130        Damen Ave & Pierce Ave
#
#                      latitude_start  longitude_start  dpcapacity_start  \
# starttime
# ...

# %%
filt = bikes2['dpcapacity_start'] > bikes2['dpcapacity_end']
bikes2[filt].head(2)
# Out:
#                      trip_id    usertype gender            stoptime  \
# starttime
# 2013-06-28 22:53:00     7524  Subscriber   Male 2013-06-28 23:03:00
# 2013-07-02 17:47:00    18880  Subscriber   Male 2013-07-02 17:56:00
#
#                      tripduration             from_station_name  \
# starttime
# 2013-06-28 22:53:00           623  Clinton St & Washington Blvd
# 2013-07-02 17:47:00           565        Clark St & Randolph St
#
#                      latitude_start  longitude_start  dpcapacity_start  \
# starttime
# 2013-06-28 22:53:00       41.883380        -87.64117              31.0
# 2013-07-02 17:47:00       41.884576        -87.63189              31.0
#
#                                      to_station_name  latitude_end  \
# starttime
# 2013-06-28 22:53:00             Wells St & Walton St      41.89993
# 2013-07-02 17:47:00  Ravenswood Ave & Irving Park Rd      41.95469
#
#                      longitude_end  dpcapacity_end  temperature  visibility  \
# starttime
# ...

# %% [markdown]
# ### Find missing values with isna

# %%
filt = bikes2['dpcapacity_start'].isna()
bikes2[filt]
# Out:
#                      trip_id    usertype  gender            stoptime  \
# starttime
# 2015-09-06 07:52:00  7319012  Subscriber    Male 2015-09-06 07:55:00
# 2015-09-07 09:52:00  7341764  Subscriber  Female 2015-09-07 09:57:00
# 2015-09-15 08:25:00  7468970  Subscriber    Male 2015-09-15 08:33:00
# 2015-10-03 21:43:00  7780399  Subscriber  Female 2015-10-03 22:04:00
# 2015-11-06 08:53:00  8207553  Subscriber  Female 2015-11-06 09:08:00
# 2015-11-18 08:55:00  8317161  Subscriber    Male 2015-11-18 09:01:00
#
#                      tripduration         from_station_name  latitude_start  \
# starttime
# 2015-09-06 07:52:00           207  Clark St & 9th St (AMLI)             NaN
# 2015-09-07 09:52:00           293  Clark St & 9th St (AMLI)             NaN
# 2015-09-15 08:25:00           473  Clark St & 9th St (AMLI)             NaN
# 2015-10-03 21:43:00          1268  Clark St & 9th St (AMLI)             NaN
# 2015-11-06 08:53:00           868  Clark St & 9th St (AMLI)             NaN
# ...

# %%
# Find out the data for particular column

cols = ['dpcapacity_start','dpcapacity_end']
bikes2.loc[filt,cols]
# Out:
#                      dpcapacity_start  dpcapacity_end
# starttime
# 2015-09-06 07:52:00               NaN            19.0
# 2015-09-07 09:52:00               NaN            19.0
# 2015-09-15 08:25:00               NaN            27.0
# 2015-10-03 21:43:00               NaN            15.0
# 2015-11-06 08:53:00               NaN            15.0
# 2015-11-18 08:55:00               NaN            19.0
